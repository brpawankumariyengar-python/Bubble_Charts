# %% [markdown]
# # This notebook uses Geopandas to generate geograhical bubble charts

# %%
import geopandas as Pawan_gpd #We import geopandas to read geoJSON file

# %%
import pandas as Pawan_pd # We import pandas to read CSV files containing various matrices that we need to analyse

# %%
import matplotlib.pyplot as Pawan_plt

# %%
Main_Folder_Path = '/Users/brpawankumar/Library/Mobile Documents/com~apple~CloudDocs/02_Python_Wala_Folder/Downloaded GeoJason Files/Municipal_Spatial_Data-master'

# %%
Bharat_Desh = Pawan_gpd.read_file("/Users/brpawankumar/Desktop/states_india 2.geojson")

# %%
Bharat_Desh
# Out:
#     cartodb_id  state_code                     st_nm  \
# 0            1           0                 Telangana
# 1            2          35  Andaman & Nicobar Island
# 2            3          28            Andhra Pradesh
# 3            4          12        Arunanchal Pradesh
# 4            5          18                     Assam
# 5            6          10                     Bihar
# 6            8          22              Chhattisgarh
# 7           10          25               Daman & Diu
# 8           11          30                       Goa
# 9           12          24                   Gujarat
# 10          13           6                   Haryana
# 11          14           2          Himachal Pradesh
# 12          15           1           Jammu & Kashmir
# 13          16          20                 Jharkhand
# 14          17          29                 Karnataka
# 15          18          32                    Kerala
# 16          19          31               Lakshadweep
# 17          20          23            Madhya Pradesh
# 18          21          27               Maharashtra
# 19          22          14                   Manipur
# 20           7           4                Chandigarh
# 21          27          34                Puducherry
# 22          28           3                    Punjab
# 23          29           8                 Rajasthan
# 24          30          11                    Sikkim
# 25          31          33                Tamil Nadu
# 26          32          16                   Tripura
# 27          33           9             Uttar Pradesh
# 28          34           5               Uttarakhand
# 29          35          19               West Bengal
# 30          36          21                    Odisha
# 31           9          26    Dadara & Nagar Havelli
# 32          23          17                 Meghalaya
# 33          24          15                   Mizoram
# 34          25          13                  Nagaland
# 35          26           7              NCT of Delhi
#
#                                              geometry
# 0   MULTIPOLYGON (((78.34088 19.88361, 78.35133 19...
# 1   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# 2   MULTIPOLYGON (((81.39375 16.33381, 81.39224 16...
# 3   MULTIPOLYGON (((96.16261 29.38078, 96.16860 29...
# 4   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# 5   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# 6   MULTIPOLYGON (((83.33532 24.09885, 83.35346 24...
# 7   MULTIPOLYGON (((72.89334 20.44539, 72.89281 20...
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# 10  MULTIPOLYGON (((76.85065 30.87512, 76.86594 30...
# 11  MULTIPOLYGON (((76.79634 33.25490, 76.80351 33...
# 12  MULTIPOLYGON (((74.73451 37.02068, 74.73647 37...
# 13  MULTIPOLYGON (((87.60582 25.31512, 87.61279 25...
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# 15  MULTIPOLYGON (((74.99575 12.79227, 75.00006 12...
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09907 11...
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# 19  MULTIPOLYGON (((94.57602 25.64221, 94.57487 25...
# 20  MULTIPOLYGON (((76.84147 30.75996, 76.83599 30...
# 21  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# 22  MULTIPOLYGON (((75.88469 32.48841, 75.90304 32...
# 23  MULTIPOLYGON (((73.89849 29.97895, 73.90021 29...
# 24  MULTIPOLYGON (((88.65381 28.09883, 88.66265 28...
# 25  MULTIPOLYGON (((78.19188 8.72729, 78.18997 8.7...
# 26  MULTIPOLYGON (((92.22109 24.50131, 92.22771 24...
# 27  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# 28  MULTIPOLYGON (((79.21047 31.34846, 79.21386 31...
# 29  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 30  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# 31  MULTIPOLYGON (((73.20657 20.12216, 73.20797 20...
# 32  MULTIPOLYGON (((91.85632 26.10353, 91.86717 26...
# 33  MULTIPOLYGON (((92.80022 24.41630, 92.80310 24...
# 34  MULTIPOLYGON (((95.21458 26.93095, 95.21719 26...
# 35  MULTIPOLYGON (((77.09361 28.86940, 77.10973 28...

# %%
Bharat_Desh.plot(cmap = 'jet', figsize = (32, 24))
# Out:
# <AxesSubplot:>

# %%
Berozgaari = Pawan_pd.read_csv('/Users/brpawankumar/Desktop/India_States_Data/Umemployment__Rate.csv')
Berozgaari
# Out:
#               States  Unemployment_Rate
# 0     Andhra Pradesh               13.5
# 1              Assam                0.1
# 2              Bihar               13.8
# 3       Chhattisgarh                8.3
# 4       NCT of Delhi               45.6
# 5                Goa               20.6
# 6            Gujarat                2.3
# 7            Haryana               29.1
# 8   Himachal Pradesh                7.8
# 9    Jammu & Kashmir               12.1
# 10         Jharkhand               16.0
# 11         Karnataka                5.3
# 12            Kerala               23.5
# 13    Madhya Pradesh                5.3
# 14       Maharashtra                5.7
# 15         Meghalaya                6.5
# 16            Odisha                7.0
# 17        Puducherry               24.0
# 18            Punjab                8.8
# 19         Rajasthan               27.6
# 20            Sikkim                4.2
# 21        Tamil Nadu               28.0
# 22         Telangana                7.4
# 23           Tripura               20.0
# 24     Uttar Pradesh                6.9
# 25       Uttarakhand                5.5
# 26       West Bengal               19.3

# %%
Ctr = 0
Mega_Merged_List =[] #This is the final list which we will use to create merged DataFrame
Unemployment = list(Berozgaari['Unemployment_Rate']) 
Selected_States = list(Bharat_Desh['st_nm'])
Bharat_Rajya = list(Berozgaari['States'])
#print("Literacy__Rate   ",Literacy__Rate)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#print("Selected_States   ",Selected_States)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#print("Bharat_Rajya   ",Bharat_Rajya)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
for Rajya in Bharat_Rajya:
        Index_Wala_Array = Bharat_Desh.st_nm[Bharat_Desh.st_nm == Rajya].index.values
        Index_Wala_Number = Index_Wala_Array[0] #We retrive the index in Bharat_Desh based upon state name
        Mega_Merged_List.append([Index_Wala_Number,Rajya,Unemployment[Ctr],Bharat_Rajya[Ctr]])
        #Here we create a merged list that will be used to create a merged dataframe 
        Ctr = Ctr + 1
        
Merged_Dataframe = Pawan_pd.DataFrame(Mega_Merged_List,columns =['Index','States','Unemployment__Rate','Rajya'])
Merged_Dataframe.sort_values(by=['Index'], inplace=True)#Merged Dataframe is sorted as per 'Index' column
print(Merged_Dataframe)
# Out:
#     Index            States  Unemployment__Rate             Rajya
# 22      0         Telangana                 7.4         Telangana
# 0       2    Andhra Pradesh                13.5    Andhra Pradesh
# 1       4             Assam                 0.1             Assam
# 2       5             Bihar                13.8             Bihar
# 3       6      Chhattisgarh                 8.3      Chhattisgarh
# 5       8               Goa                20.6               Goa
# 6       9           Gujarat                 2.3           Gujarat
# 7      10           Haryana                29.1           Haryana
# 8      11  Himachal Pradesh                 7.8  Himachal Pradesh
# 9      12   Jammu & Kashmir                12.1   Jammu & Kashmir
# 10     13         Jharkhand                16.0         Jharkhand
# 11     14         Karnataka                 5.3         Karnataka
# 12     15            Kerala                23.5            Kerala
# 13     17    Madhya Pradesh                 5.3    Madhya Pradesh
# 14     18       Maharashtra                 5.7       Maharashtra
# 17     21        Puducherry                24.0        Puducherry
# 18     22            Punjab                 8.8            Punjab
# 19     23         Rajasthan                27.6         Rajasthan
# 20     24            Sikkim                 4.2            Sikkim
# 21     25        Tamil Nadu                28.0        Tamil Nadu
# 23     26           Tripura                20.0           Tripura
# 24     27     Uttar Pradesh                 6.9     Uttar Pradesh
# 25     28       Uttarakhand                 5.5       Uttarakhand
# 26     29       West Bengal                19.3       West Bengal
# 16     30            Odisha                 7.0            Odisha
# 15     32         Meghalaya                 6.5         Meghalaya
# 4      35      NCT of Delhi                45.6      NCT of Delhi

# %%
Merged_Dataframe.reset_index(inplace=True) #We reset the index so that generation of lists can be easy
print(Merged_Dataframe)
List_Main_Index = list(Merged_Dataframe['Index'])
List_Prep_Unemployment_Rate = list(Merged_Dataframe['Unemployment__Rate'])
# Out:
#     index  Index            States  Unemployment__Rate             Rajya
# 0      22      0         Telangana                 7.4         Telangana
# 1       0      2    Andhra Pradesh                13.5    Andhra Pradesh
# 2       1      4             Assam                 0.1             Assam
# 3       2      5             Bihar                13.8             Bihar
# 4       3      6      Chhattisgarh                 8.3      Chhattisgarh
# 5       5      8               Goa                20.6               Goa
# 6       6      9           Gujarat                 2.3           Gujarat
# 7       7     10           Haryana                29.1           Haryana
# 8       8     11  Himachal Pradesh                 7.8  Himachal Pradesh
# 9       9     12   Jammu & Kashmir                12.1   Jammu & Kashmir
# 10     10     13         Jharkhand                16.0         Jharkhand
# 11     11     14         Karnataka                 5.3         Karnataka
# 12     12     15            Kerala                23.5            Kerala
# 13     13     17    Madhya Pradesh                 5.3    Madhya Pradesh
# 14     14     18       Maharashtra                 5.7       Maharashtra
# 15     17     21        Puducherry                24.0        Puducherry
# 16     18     22            Punjab                 8.8            Punjab
# 17     19     23         Rajasthan                27.6         Rajasthan
# 18     20     24            Sikkim                 4.2            Sikkim
# 19     21     25        Tamil Nadu                28.0        Tamil Nadu
# 20     23     26           Tripura                20.0           Tripura
# 21     24     27     Uttar Pradesh                 6.9     Uttar Pradesh
# 22     25     28       Uttarakhand                 5.5       Uttarakhand
# 23     26     29       West Bengal                19.3       West Bengal
# 24     16     30            Odisha                 7.0            Odisha
# 25     15     32         Meghalaya                 6.5         Meghalaya
# 26      4     35      NCT of Delhi                45.6      NCT of Delhi

# %%
Final_Unemployment_Rate = []

Ctr = 0

while Ctr < len(Selected_States):
    Is_Element_Present = Ctr in List_Main_Index
    if Is_Element_Present == True:
        Temporary_Index = List_Main_Index.index(Ctr)
        Temporary_Unemployment_Rate = List_Prep_Unemployment_Rate[Temporary_Index ]
        Final_Unemployment_Rate.append(Temporary_Unemployment_Rate * 10)
    else:
        Final_Unemployment_Rate.append(0)
    Ctr = Ctr+ 1
print(Final_Unemployment_Rate)
# Out:
# [74.0, 0, 135.0, 0, 1.0, 138.0, 83.0, 0, 206.0, 23.0, 291.0, 78.0, 121.0, 160.0, 53.0, 235.0, 0, 53.0, 57.0, 0, 0, 240.0, 88.0, 276.0, 42.0, 280.0, 200.0, 69.0, 55.0, 193.0, 70.0, 0, 65.0, 0, 0, 456.0]

# %%
Bharat_Desh['Unemployment_Rate'] = Final_Unemployment_Rate

# %%
Bharat_Desh
# Out:
#     cartodb_id  state_code                     st_nm  \
# 0            1           0                 Telangana
# 1            2          35  Andaman & Nicobar Island
# 2            3          28            Andhra Pradesh
# 3            4          12        Arunanchal Pradesh
# 4            5          18                     Assam
# 5            6          10                     Bihar
# 6            8          22              Chhattisgarh
# 7           10          25               Daman & Diu
# 8           11          30                       Goa
# 9           12          24                   Gujarat
# 10          13           6                   Haryana
# 11          14           2          Himachal Pradesh
# 12          15           1           Jammu & Kashmir
# 13          16          20                 Jharkhand
# 14          17          29                 Karnataka
# 15          18          32                    Kerala
# 16          19          31               Lakshadweep
# 17          20          23            Madhya Pradesh
# 18          21          27               Maharashtra
# 19          22          14                   Manipur
# 20           7           4                Chandigarh
# 21          27          34                Puducherry
# 22          28           3                    Punjab
# 23          29           8                 Rajasthan
# 24          30          11                    Sikkim
# 25          31          33                Tamil Nadu
# 26          32          16                   Tripura
# 27          33           9             Uttar Pradesh
# 28          34           5               Uttarakhand
# 29          35          19               West Bengal
# 30          36          21                    Odisha
# 31           9          26    Dadara & Nagar Havelli
# 32          23          17                 Meghalaya
# 33          24          15                   Mizoram
# 34          25          13                  Nagaland
# 35          26           7              NCT of Delhi
#
#                                              geometry  Unemployment_Rate
# 0   MULTIPOLYGON (((78.34088 19.88361, 78.35133 19...               74.0
# 1   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...                0.0
# 2   MULTIPOLYGON (((81.39375 16.33381, 81.39224 16...              135.0
# 3   MULTIPOLYGON (((96.16261 29.38078, 96.16860 29...                0.0
# 4   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...                1.0
# 5   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...              138.0
# 6   MULTIPOLYGON (((83.33532 24.09885, 83.35346 24...               83.0
# 7   MULTIPOLYGON (((72.89334 20.44539, 72.89281 20...                0.0
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...              206.0
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...               23.0
# 10  MULTIPOLYGON (((76.85065 30.87512, 76.86594 30...              291.0
# 11  MULTIPOLYGON (((76.79634 33.25490, 76.80351 33...               78.0
# 12  MULTIPOLYGON (((74.73451 37.02068, 74.73647 37...              121.0
# 13  MULTIPOLYGON (((87.60582 25.31512, 87.61279 25...              160.0
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...               53.0
# 15  MULTIPOLYGON (((74.99575 12.79227, 75.00006 12...              235.0
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09907 11...                0.0
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...               53.0
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...               57.0
# 19  MULTIPOLYGON (((94.57602 25.64221, 94.57487 25...                0.0
# 20  MULTIPOLYGON (((76.84147 30.75996, 76.83599 30...                0.0
# 21  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...              240.0
# 22  MULTIPOLYGON (((75.88469 32.48841, 75.90304 32...               88.0
# 23  MULTIPOLYGON (((73.89849 29.97895, 73.90021 29...              276.0
# 24  MULTIPOLYGON (((88.65381 28.09883, 88.66265 28...               42.0
# 25  MULTIPOLYGON (((78.19188 8.72729, 78.18997 8.7...              280.0
# 26  MULTIPOLYGON (((92.22109 24.50131, 92.22771 24...              200.0
# 27  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...               69.0
# 28  MULTIPOLYGON (((79.21047 31.34846, 79.21386 31...               55.0
# 29  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...              193.0
# 30  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...               70.0
# 31  MULTIPOLYGON (((73.20657 20.12216, 73.20797 20...                0.0
# 32  MULTIPOLYGON (((91.85632 26.10353, 91.86717 26...               65.0
# 33  MULTIPOLYGON (((92.80022 24.41630, 92.80310 24...                0.0
# 34  MULTIPOLYGON (((95.21458 26.93095, 95.21719 26...                0.0
# 35  MULTIPOLYGON (((77.09361 28.86940, 77.10973 28...              456.0

# %%
fig, ax = Pawan_plt.subplots(figsize = (32, 24))
Pawan_plt.title("Plotting_Unempolyment_Rate_In_Indian_States")
Bharat_Desh.plot(ax = ax, column = 'Unemployment_Rate',cmap ='YlGnBu', edgecolor = 'red', linewidth = 0.5, legend = True)
ax.axis("off")
Pawan_plt.show()
