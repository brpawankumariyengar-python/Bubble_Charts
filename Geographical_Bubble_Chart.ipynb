# %% [markdown]
# # This notebook uses Geopandas to generate geograhical bubble charts

# %%
import geopandas as Pawan_gpd #We import geopandas to read geoJSON file

# %%
import pandas as Pawan_pd # We import pandas to read CSV files containing various matrices that we need to analyse

# %%
import matplotlib.pyplot as Pawan_plt

# %%
Main_Folder_Path = '/Users/brpawankumar/Library/Mobile Documents/com~apple~CloudDocs/02_Python_Wala_Folder/Downloaded GeoJason Files/Municipal_Spatial_Data-master'

# %%
Bharat_Desh = Pawan_gpd.read_file("/Users/brpawankumar/Desktop/states_india 2.geojson")

# %%
Bharat_Desh
# Out:
#     cartodb_id  state_code                     st_nm  \
# 0            1           0                 Telangana
# 1            2          35  Andaman & Nicobar Island
# 2            3          28            Andhra Pradesh
# 3            4          12        Arunanchal Pradesh
# 4            5          18                     Assam
# 5            6          10                     Bihar
# 6            8          22              Chhattisgarh
# 7           10          25               Daman & Diu
# 8           11          30                       Goa
# 9           12          24                   Gujarat
# 10          13           6                   Haryana
# 11          14           2          Himachal Pradesh
# 12          15           1           Jammu & Kashmir
# 13          16          20                 Jharkhand
# 14          17          29                 Karnataka
# 15          18          32                    Kerala
# 16          19          31               Lakshadweep
# 17          20          23            Madhya Pradesh
# 18          21          27               Maharashtra
# 19          22          14                   Manipur
# 20           7           4                Chandigarh
# 21          27          34                Puducherry
# 22          28           3                    Punjab
# 23          29           8                 Rajasthan
# 24          30          11                    Sikkim
# 25          31          33                Tamil Nadu
# 26          32          16                   Tripura
# 27          33           9             Uttar Pradesh
# 28          34           5               Uttarakhand
# 29          35          19               West Bengal
# 30          36          21                    Odisha
# 31           9          26    Dadara & Nagar Havelli
# 32          23          17                 Meghalaya
# 33          24          15                   Mizoram
# 34          25          13                  Nagaland
# 35          26           7              NCT of Delhi
#
#                                              geometry
# 0   MULTIPOLYGON (((78.34088 19.88361, 78.35133 19...
# 1   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# 2   MULTIPOLYGON (((81.39375 16.33381, 81.39224 16...
# 3   MULTIPOLYGON (((96.16261 29.38078, 96.16860 29...
# 4   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# 5   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# 6   MULTIPOLYGON (((83.33532 24.09885, 83.35346 24...
# 7   MULTIPOLYGON (((72.89334 20.44539, 72.89281 20...
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# 10  MULTIPOLYGON (((76.85065 30.87512, 76.86594 30...
# 11  MULTIPOLYGON (((76.79634 33.25490, 76.80351 33...
# 12  MULTIPOLYGON (((74.73451 37.02068, 74.73647 37...
# 13  MULTIPOLYGON (((87.60582 25.31512, 87.61279 25...
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# 15  MULTIPOLYGON (((74.99575 12.79227, 75.00006 12...
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09907 11...
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# 19  MULTIPOLYGON (((94.57602 25.64221, 94.57487 25...
# 20  MULTIPOLYGON (((76.84147 30.75996, 76.83599 30...
# 21  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# 22  MULTIPOLYGON (((75.88469 32.48841, 75.90304 32...
# 23  MULTIPOLYGON (((73.89849 29.97895, 73.90021 29...
# 24  MULTIPOLYGON (((88.65381 28.09883, 88.66265 28...
# 25  MULTIPOLYGON (((78.19188 8.72729, 78.18997 8.7...
# 26  MULTIPOLYGON (((92.22109 24.50131, 92.22771 24...
# 27  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# 28  MULTIPOLYGON (((79.21047 31.34846, 79.21386 31...
# 29  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 30  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# 31  MULTIPOLYGON (((73.20657 20.12216, 73.20797 20...
# 32  MULTIPOLYGON (((91.85632 26.10353, 91.86717 26...
# 33  MULTIPOLYGON (((92.80022 24.41630, 92.80310 24...
# 34  MULTIPOLYGON (((95.21458 26.93095, 95.21719 26...
# 35  MULTIPOLYGON (((77.09361 28.86940, 77.10973 28...

# %%
Bharat_Desh.plot(cmap = 'jet', figsize = (32, 24))
# Out:
# <AxesSubplot:>

# %%
Padhai_Likhai = Pawan_pd.read_csv('/Users/brpawankumar/Desktop/India_States_Data/Literacy_Rates_India.csv')
Padhai_Likhai
# Out:
#               States  Overall Literacy Rate
# 0     Andhra Pradesh                   66.4
# 1          Rajasthan                   69.7
# 2              Bihar                   70.9
# 3          Telangana                   72.8
# 4      Uttar Pradesh                   73.0
# 5     Madhya Pradesh                   73.7
# 6          Jharkhand                   74.3
# 7          Karnataka                   77.2
# 8       Chhattisgarh                   77.3
# 9    Jammu & Kashmir                   77.3
# 10            Odisha                   77.3
# 11           Haryana                   80.4
# 12       West Bengal                   80.5
# 13           Gujarat                   82.4
# 14        Tamil Nadu                   82.9
# 15            Punjab                   83.7
# 16       Maharashtra                   84.8
# 17             Assam                   85.9
# 18  Himachal Pradesh                   86.6
# 19       Uttarakhand                   87.6
# 20      NCT of Delhi                   88.7
# 21            Kerala                   96.2

# %%
Ctr = 0
Mega_Merged_List =[] #This is the final list which we will use to create merged DataFrame
Literacy__Rate = list(Padhai_Likhai['Overall Literacy Rate']) 
Selected_States = list(Bharat_Desh['st_nm'])
Bharat_Rajya = list(Padhai_Likhai['States'])
#print("Literacy__Rate   ",Literacy__Rate)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#print("Selected_States   ",Selected_States)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#print("Bharat_Rajya   ",Bharat_Rajya)
#print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
for Rajya in Bharat_Rajya:
        Index_Wala_Array = Bharat_Desh.st_nm[Bharat_Desh.st_nm == Rajya].index.values
        Index_Wala_Number = Index_Wala_Array[0] #We retrive the index in Bharat_Desh based upon state name
        Mega_Merged_List.append([Index_Wala_Number,Rajya,Literacy__Rate[Ctr],Bharat_Rajya[Ctr]])
        #Here we create a merged list that will be used to create a merged dataframe 
        Ctr = Ctr + 1
        
Merged_Dataframe = Pawan_pd.DataFrame(Mega_Merged_List,columns =['Index','States','Literacy__Rate','Rajya'])
Merged_Dataframe.sort_values(by=['Index'], inplace=True)#Merged Dataframe is sorted as per 'Index' column
print(Merged_Dataframe)
# Out:
#     Index            States  Literacy__Rate             Rajya
# 3       0         Telangana            72.8         Telangana
# 0       2    Andhra Pradesh            66.4    Andhra Pradesh
# 17      4             Assam            85.9             Assam
# 2       5             Bihar            70.9             Bihar
# 8       6      Chhattisgarh            77.3      Chhattisgarh
# 13      9           Gujarat            82.4           Gujarat
# 11     10           Haryana            80.4           Haryana
# 18     11  Himachal Pradesh            86.6  Himachal Pradesh
# 9      12   Jammu & Kashmir            77.3   Jammu & Kashmir
# 6      13         Jharkhand            74.3         Jharkhand
# 7      14         Karnataka            77.2         Karnataka
# 21     15            Kerala            96.2            Kerala
# 5      17    Madhya Pradesh            73.7    Madhya Pradesh
# 16     18       Maharashtra            84.8       Maharashtra
# 15     22            Punjab            83.7            Punjab
# 1      23         Rajasthan            69.7         Rajasthan
# 14     25        Tamil Nadu            82.9        Tamil Nadu
# 4      27     Uttar Pradesh            73.0     Uttar Pradesh
# 19     28       Uttarakhand            87.6       Uttarakhand
# 12     29       West Bengal            80.5       West Bengal
# 10     30            Odisha            77.3            Odisha
# 20     35      NCT of Delhi            88.7      NCT of Delhi

# %%
Merged_Dataframe.reset_index(inplace=True) #We reset the index so that generation of lists can be easy
print(Merged_Dataframe)
List_Main_Index = list(Merged_Dataframe['Index'])
List_Prep_Literacy_Rate = list(Merged_Dataframe['Literacy__Rate'])
# Out:
#     index  Index            States  Literacy__Rate             Rajya
# 0       3      0         Telangana            72.8         Telangana
# 1       0      2    Andhra Pradesh            66.4    Andhra Pradesh
# 2      17      4             Assam            85.9             Assam
# 3       2      5             Bihar            70.9             Bihar
# 4       8      6      Chhattisgarh            77.3      Chhattisgarh
# 5      13      9           Gujarat            82.4           Gujarat
# 6      11     10           Haryana            80.4           Haryana
# 7      18     11  Himachal Pradesh            86.6  Himachal Pradesh
# 8       9     12   Jammu & Kashmir            77.3   Jammu & Kashmir
# 9       6     13         Jharkhand            74.3         Jharkhand
# 10      7     14         Karnataka            77.2         Karnataka
# 11     21     15            Kerala            96.2            Kerala
# 12      5     17    Madhya Pradesh            73.7    Madhya Pradesh
# 13     16     18       Maharashtra            84.8       Maharashtra
# 14     15     22            Punjab            83.7            Punjab
# 15      1     23         Rajasthan            69.7         Rajasthan
# 16     14     25        Tamil Nadu            82.9        Tamil Nadu
# 17      4     27     Uttar Pradesh            73.0     Uttar Pradesh
# 18     19     28       Uttarakhand            87.6       Uttarakhand
# 19     12     29       West Bengal            80.5       West Bengal
# 20     10     30            Odisha            77.3            Odisha
# 21     20     35      NCT of Delhi            88.7      NCT of Delhi

# %%
Final_Literacy_Rate = []

Ctr = 0

while Ctr < len(Selected_States):
    Is_Element_Present = Ctr in List_Main_Index
    if Is_Element_Present == True:
        Temporary_Index = List_Main_Index.index(Ctr)
        Temporary_Litracy_Rate = List_Prep_Literacy_Rate[Temporary_Index ]
        Final_Literacy_Rate.append(Temporary_Litracy_Rate * 100)
    else:
        Final_Literacy_Rate.append(0)
    Ctr = Ctr+ 1
print(Final_Literacy_Rate)
# Out:
# [7280.0, 0, 6640.000000000001, 0, 8590.0, 7090.000000000001, 7730.0, 0, 0, 8240.0, 8040.000000000001, 8660.0, 7730.0, 7430.0, 7720.0, 9620.0, 0, 7370.0, 8480.0, 0, 0, 0, 8370.0, 6970.0, 0, 8290.0, 0, 7300.0, 8760.0, 8050.0, 7730.0, 0, 0, 0, 0, 8870.0]

# %%
Bharat_Desh['Literacy_Rate'] = Final_Literacy_Rate

# %%
Bharat_Desh
# Out:
#     cartodb_id  state_code                     st_nm  \
# 0            1           0                 Telangana
# 1            2          35  Andaman & Nicobar Island
# 2            3          28            Andhra Pradesh
# 3            4          12        Arunanchal Pradesh
# 4            5          18                     Assam
# 5            6          10                     Bihar
# 6            8          22              Chhattisgarh
# 7           10          25               Daman & Diu
# 8           11          30                       Goa
# 9           12          24                   Gujarat
# 10          13           6                   Haryana
# 11          14           2          Himachal Pradesh
# 12          15           1           Jammu & Kashmir
# 13          16          20                 Jharkhand
# 14          17          29                 Karnataka
# 15          18          32                    Kerala
# 16          19          31               Lakshadweep
# 17          20          23            Madhya Pradesh
# 18          21          27               Maharashtra
# 19          22          14                   Manipur
# 20           7           4                Chandigarh
# 21          27          34                Puducherry
# 22          28           3                    Punjab
# 23          29           8                 Rajasthan
# 24          30          11                    Sikkim
# 25          31          33                Tamil Nadu
# 26          32          16                   Tripura
# 27          33           9             Uttar Pradesh
# 28          34           5               Uttarakhand
# 29          35          19               West Bengal
# 30          36          21                    Odisha
# 31           9          26    Dadara & Nagar Havelli
# 32          23          17                 Meghalaya
# 33          24          15                   Mizoram
# 34          25          13                  Nagaland
# 35          26           7              NCT of Delhi
#
#                                              geometry  Literacy_Rate
# 0   MULTIPOLYGON (((78.34088 19.88361, 78.35133 19...         7280.0
# 1   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...            0.0
# 2   MULTIPOLYGON (((81.39375 16.33381, 81.39224 16...         6640.0
# 3   MULTIPOLYGON (((96.16261 29.38078, 96.16860 29...            0.0
# 4   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...         8590.0
# 5   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...         7090.0
# 6   MULTIPOLYGON (((83.33532 24.09885, 83.35346 24...         7730.0
# 7   MULTIPOLYGON (((72.89334 20.44539, 72.89281 20...            0.0
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...            0.0
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...         8240.0
# 10  MULTIPOLYGON (((76.85065 30.87512, 76.86594 30...         8040.0
# 11  MULTIPOLYGON (((76.79634 33.25490, 76.80351 33...         8660.0
# 12  MULTIPOLYGON (((74.73451 37.02068, 74.73647 37...         7730.0
# 13  MULTIPOLYGON (((87.60582 25.31512, 87.61279 25...         7430.0
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...         7720.0
# 15  MULTIPOLYGON (((74.99575 12.79227, 75.00006 12...         9620.0
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09907 11...            0.0
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...         7370.0
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...         8480.0
# 19  MULTIPOLYGON (((94.57602 25.64221, 94.57487 25...            0.0
# 20  MULTIPOLYGON (((76.84147 30.75996, 76.83599 30...            0.0
# 21  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...            0.0
# 22  MULTIPOLYGON (((75.88469 32.48841, 75.90304 32...         8370.0
# 23  MULTIPOLYGON (((73.89849 29.97895, 73.90021 29...         6970.0
# 24  MULTIPOLYGON (((88.65381 28.09883, 88.66265 28...            0.0
# 25  MULTIPOLYGON (((78.19188 8.72729, 78.18997 8.7...         8290.0
# 26  MULTIPOLYGON (((92.22109 24.50131, 92.22771 24...            0.0
# 27  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...         7300.0
# 28  MULTIPOLYGON (((79.21047 31.34846, 79.21386 31...         8760.0
# 29  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...         8050.0
# 30  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...         7730.0
# 31  MULTIPOLYGON (((73.20657 20.12216, 73.20797 20...            0.0
# 32  MULTIPOLYGON (((91.85632 26.10353, 91.86717 26...            0.0
# 33  MULTIPOLYGON (((92.80022 24.41630, 92.80310 24...            0.0
# 34  MULTIPOLYGON (((95.21458 26.93095, 95.21719 26...            0.0
# 35  MULTIPOLYGON (((77.09361 28.86940, 77.10973 28...         8870.0

# %%
fig, ax = Pawan_plt.subplots(figsize = (32, 24))
Pawan_plt.title("Yeh kya ho raha hain")
Bharat_Desh.plot(ax = ax, column = 'Literacy_Rate',cmap ='YlGnBu', edgecolor = 'red', linewidth = 0.5, legend = True)
ax.axis("off")
Pawan_plt.show()
